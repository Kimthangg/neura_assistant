# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from bot.agent_extraction.create_event.prompt_create_normal_event import create_event_normal
create_event_normal()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 import os
#       3 sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
# ----> 5 from bot.agent_extraction.create_event.prompt_create_normal_event import create_event_normal
#       6 create_event_normal()
#
# File d:\Môn học\Tài liệu học\Năm 4\Kì 2\Đồ án thực tập\Code\bot\__init__.py:1
# ----> 1 from .handler import *
#       2 from .agent_extraction import *
#       3 from .agent_intent  import *
#
# File d:\Môn học\Tài liệu học\Năm 4\Kì 2\Đồ án thực tập\Code\bot\handler\__init__.py:1
# ----> 1 from .message import *
#       2 from .gen import *
#
# File d:\Môn học\Tài liệu học\Năm 4\Kì 2\Đồ án thực tập\Code\bot\handler\message.py:1
# ----> 1 from bot.agent_intent import intent_model
#       2 from bot.agent_extraction import *
#       3 from features import *
#
# ...
